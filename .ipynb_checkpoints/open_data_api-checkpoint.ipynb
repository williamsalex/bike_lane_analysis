# %%
import requests
import math
import json
import pandas as pd
import numpy as np
import re
from sodapy import Socrata
import multiprocessing
import psycopg2

# %%
def quick_dist(coord1, coord2):
    """
    A function to rapidly calculate distances without trigonometry using constants local to New York City.
    """
    return math.sqrt(math.pow(12430*((coord1[1]-coord2[1])/180),2)+math.pow(24901*((coord1[0]-coord2[0])/360)*0.16133111759,2))

# %%
def retrieve_data():
    """
    Pulls data from NYC Open Data using their SODA APIs.
    """
    client = Socrata("data.cityofnewyork.us", None)
    return {'crashes': client.get("h9gi-nx95", limit=100000000), 
            'centerlines': client.get("yfsx-e2j3", limit=100000000), 
            'lanes': client.get("cc5c-sm6z", limit=100000000)}

# %%
data = retrieve_data()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
def filter_crashes(data):
    regex = r"vehicle_type_code\d+"
    bike_accidents = []
    errors = 0
    for crash in data['crashes']:
        for item in crash.keys():
            if re.match(regex, item) and crash[item] == 'Bike' and int(crash['number_of_cyclist_injured'] + crash['number_of_cyclist_killed']) > 0:
                try:
                    bike_accidents.append({
                        'date': crash['crash_date'],
                        'time': crash['crash_time'],
                        'latitude': float(crash['latitude']),
                        'longitude': float(crash['longitude']),
                        'number_of_cyclist_injured': crash['number_of_cyclist_injured'],
                        'number_of_cyclist_killed': crash['number_of_cyclist_killed'],
                    })
                except:
                    pass
                break
    data['crashes'] = bike_accidents

# %%
def clean_lanes(data):
    lane_assembly = {}
    new_lane_dataset = []
    for lane in data['lanes']:
        lane_assembly['on_street'] = lane['onoffst'] == 'ON'
        lane_assembly['directional_width'] = lane['lanecount']
        if 'ft_facilit' in lane.keys():
            lane_assembly['infrastructure'] = lane['ft_facilit']
        elif 'tf_facilit' in lane.keys():
            lane_assembly['infrastructure'] = lane['tf_facilit']
        else:
            lane_assembly['infrastructure'] = 'unknown'
        if lane['bikedir'] == 'L':
            lane_assembly['first_coord'] = lane['the_geom']['coordinates'][0][1]
            lane_assembly['second_coord'] = lane['the_geom']['coordinates'][0][0]
        else:
            lane_assembly['first_coord'] = lane['the_geom']['coordinates'][0][0]
            lane_assembly['second_coord'] = lane['the_geom']['coordinates'][0][1]
            if lane['bikedir'] == '2':
                lane_assembly['direction'] = 'two-way'
            if lane['bikedir'] == 'X':
                lane_assembly['direction'] = 'construction'
        new_lane_dataset.append(lane_assembly)
        lane_assembly = {}
    data['lanes'] = new_lane_dataset

# %%
filter_crashes(data)
clean_lanes(data)

# %%
data['crashes']
# Out:
# [{'date': '2019-06-29T00:00:00.000',
#   'time': '16:05',
#   'latitude': 40.66597,
#   'longitude': -73.928604,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-07-01T00:00:00.000',
#   'time': '21:17',
#   'latitude': 40.8785,
#   'longitude': -73.902016,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-29T00:00:00.000',
#   'time': '17:00',
#   'latitude': 40.814102,
#   'longitude': -73.940865,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-24T00:00:00.000',
#   'time': '16:00',
#   'latitude': 40.70407,
#   'longitude': -73.85962,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-14T00:00:00.000',
#   'time': '17:44',
#   'latitude': 40.762226,
#   'longitude': -73.96819,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-07-02T00:00:00.000',
#   'time': '0:22',
#   'latitude': 40.677353,
#   'longitude': -73.94424,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-14T00:00:00.000',
#   'time': '15:36',
#   'latitude': 40.862717,
#   'longitude': -73.9023,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-30T00:00:00.000',
#   'time': '13:50',
#   'latitude': 40.760494,
#   'longitude': -73.8614,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-22T00:00:00.000',
#   'time': '20:15',
#   'latitude': 40.673267,
#   'longitude': -73.98952,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-26T00:00:00.000',
#   'time': '8:55',
#   'latitude': 40.666275,
#   'longitude': -73.93415,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-25T00:00:00.000',
#   'time': '10:30',
#   'latitude': 40.830368,
#   'longitude': -73.89718,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-21T00:00:00.000',
#   'time': '21:00',
#   'latitude': 40.88152,
#   'longitude': -73.82981,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-14T00:00:00.000',
#   'time': '18:53',
#   'latitude': 40.70193,
#   'longitude': -73.881004,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-22T00:00:00.000',
#   'time': '14:00',
#   'latitude': 40.696117,
#   'longitude': -73.970436,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-26T00:00:00.000',
#   'time': '12:04',
#   'latitude': 40.842262,
#   'longitude': -73.839,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-24T00:00:00.000',
#   'time': '16:05',
#   'latitude': 40.815304,
#   'longitude': -73.94371,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-09T00:00:00.000',
#   'time': '8:05',
#   'latitude': 40.692245,
#   'longitude': -73.801216,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-07-02T00:00:00.000',
#   'time': '21:20',
#   'latitude': 40.642372,
#   'longitude': -73.957466,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-16T00:00:00.000',
#   'time': '23:25',
#   'latitude': 40.761177,
#   'longitude': -73.97317,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-28T00:00:00.000',
#   'time': '16:55',
#   'latitude': 40.581146,
#   'longitude': -73.98233,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-18T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.630512,
#   'longitude': -73.957306,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-24T00:00:00.000',
#   'time': '19:40',
#   'latitude': 40.708252,
#   'longitude': -73.781456,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-11T00:00:00.000',
#   'time': '17:03',
#   'latitude': 40.640198,
#   'longitude': -73.99493,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-23T00:00:00.000',
#   'time': '21:00',
#   'latitude': 40.70636,
#   'longitude': -73.95192,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-26T00:00:00.000',
#   'time': '22:20',
#   'latitude': 40.77226,
#   'longitude': -73.92591,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-07-02T00:00:00.000',
#   'time': '10:30',
#   'latitude': 40.747295,
#   'longitude': -73.97405,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-18T00:00:00.000',
#   'time': '17:50',
#   'latitude': 40.729706,
#   'longitude': -74.00922,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-27T00:00:00.000',
#   'time': '21:00',
#   'latitude': 40.686085,
#   'longitude': -73.982666,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-10T00:00:00.000',
#   'time': '12:36',
#   'latitude': 40.74612,
#   'longitude': -73.86824,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-28T00:00:00.000',
#   'time': '18:40',
#   'latitude': 40.845985,
#   'longitude': -73.884476,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-26T00:00:00.000',
#   'time': '15:30',
#   'latitude': 40.69083,
#   'longitude': -73.9244,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-24T00:00:00.000',
#   'time': '8:50',
#   'latitude': 40.808838,
#   'longitude': -73.92229,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-17T00:00:00.000',
#   'time': '9:30',
#   'latitude': 40.725796,
#   'longitude': -73.986626,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-26T00:00:00.000',
#   'time': '21:26',
#   'latitude': 40.812572,
#   'longitude': -73.950935,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-09T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.753937,
#   'longitude': -73.8603,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-12T00:00:00.000',
#   'time': '18:23',
#   'latitude': 40.59622,
#   'longitude': -73.980225,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-19T00:00:00.000',
#   'time': '13:10',
#   'latitude': 40.825573,
#   'longitude': -73.918465,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-15T00:00:00.000',
#   'time': '10:00',
#   'latitude': 40.618374,
#   'longitude': -73.9097,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-22T00:00:00.000',
#   'time': '16:36',
#   'latitude': 40.73321,
#   'longitude': -73.99112,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-16T00:00:00.000',
#   'time': '9:30',
#   'latitude': 40.793186,
#   'longitude': -73.94057,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-23T00:00:00.000',
#   'time': '9:00',
#   'latitude': 40.69613,
#   'longitude': -73.987114,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-11T00:00:00.000',
#   'time': '22:05',
#   'latitude': 40.805836,
#   'longitude': -73.94691,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-09T00:00:00.000',
#   'time': '14:26',
#   'latitude': 40.74603,
#   'longitude': -73.913376,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-25T00:00:00.000',
#   'time': '21:45',
#   'latitude': 40.70798,
#   'longitude': -74.00617,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-11T00:00:00.000',
#   'time': '14:05',
#   'latitude': 40.59011,
#   'longitude': -73.97422,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-14T00:00:00.000',
#   'time': '13:50',
#   'latitude': 40.824703,
#   'longitude': -73.944275,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '17:10',
#   'latitude': 40.788532,
#   'longitude': -73.95322,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '19:11',
#   'latitude': 40.87033,
#   'longitude': -73.87827,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '20:57',
#   'latitude': 40.790623,
#   'longitude': -73.942444,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '22:15',
#   'latitude': 40.672348,
#   'longitude': -73.91409,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '9:30',
#   'latitude': 40.758007,
#   'longitude': -73.96625,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '16:12',
#   'latitude': 40.720318,
#   'longitude': -73.96173,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '17:43',
#   'latitude': 40.721275,
#   'longitude': -73.9778,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '16:33',
#   'latitude': 40.879887,
#   'longitude': -73.88585,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '10:00',
#   'latitude': 40.580772,
#   'longitude': -73.96556,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-22T00:00:00.000',
#   'time': '11:50',
#   'latitude': 40.74309,
#   'longitude': -73.97402,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '9:31',
#   'latitude': 40.723686,
#   'longitude': -73.99648,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '21:28',
#   'latitude': 40.742783,
#   'longitude': -73.98235,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '15:00',
#   'latitude': 40.755505,
#   'longitude': -73.96807,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '23:50',
#   'latitude': 40.68564,
#   'longitude': -73.73396,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '9:37',
#   'latitude': 40.742844,
#   'longitude': -73.85122,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '11:30',
#   'latitude': 40.854168,
#   'longitude': -73.93371,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '16:47',
#   'latitude': 40.753708,
#   'longitude': -73.90299,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '16:00',
#   'latitude': 40.6869,
#   'longitude': -73.92352,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '13:00',
#   'latitude': 40.68175,
#   'longitude': -73.96748,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '20:51',
#   'latitude': 40.713135,
#   'longitude': -74.00407,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-28T00:00:00.000',
#   'time': '8:30',
#   'latitude': 40.71299,
#   'longitude': -73.98591,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '20:20',
#   'latitude': 40.743755,
#   'longitude': -73.99275,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '20:35',
#   'latitude': 40.671593,
#   'longitude': -73.9843,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '19:21',
#   'latitude': 40.774277,
#   'longitude': -73.959404,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '18:45',
#   'latitude': 40.858223,
#   'longitude': -73.88764,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.71138,
#   'longitude': -73.96645,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '18:20',
#   'latitude': 40.723213,
#   'longitude': -74.00621,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.64663,
#   'longitude': -73.95566,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '17:55',
#   'latitude': 40.753998,
#   'longitude': -73.94244,
#   'number_of_cyclist_injured': '2',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '11:05',
#   'latitude': 40.728134,
#   'longitude': -73.95328,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '20:30',
#   'latitude': 40.74998,
#   'longitude': -73.861664,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-26T00:00:00.000',
#   'time': '12:34',
#   'latitude': 40.81608,
#   'longitude': -73.917694,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '14:52',
#   'latitude': 40.78202,
#   'longitude': -73.97173,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-16T00:00:00.000',
#   'time': '16:30',
#   'latitude': 40.630627,
#   'longitude': -73.926186,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '4:55',
#   'latitude': 40.64759,
#   'longitude': -74.01142,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '13:25',
#   'latitude': 40.87683,
#   'longitude': -73.86472,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-22T00:00:00.000',
#   'time': '21:58',
#   'latitude': 40.696823,
#   'longitude': -73.91487,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '14:05',
#   'latitude': 40.76134,
#   'longitude': -73.97417,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '15:50',
#   'latitude': 40.782238,
#   'longitude': -73.980225,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '20:38',
#   'latitude': 40.698257,
#   'longitude': -73.74393,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '19:25',
#   'latitude': 40.692226,
#   'longitude': -73.930916,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '17:30',
#   'latitude': 40.703285,
#   'longitude': -73.950645,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '17:20',
#   'latitude': 40.732403,
#   'longitude': -74.0102,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '18:10',
#   'latitude': 40.778484,
#   'longitude': -73.94526,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '19:10',
#   'latitude': 40.68668,
#   'longitude': -73.97937,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '17:50',
#   'latitude': 40.77944,
#   'longitude': -73.809,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '18:45',
#   'latitude': 40.59601,
#   'longitude': -73.74267,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '14:00',
#   'latitude': 40.716278,
#   'longitude': -74.00454,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '12:15',
#   'latitude': 40.635372,
#   'longitude': -73.988174,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '13:20',
#   'latitude': 40.750763,
#   'longitude': -73.97446,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '17:49',
#   'latitude': 40.57981,
#   'longitude': -73.837204,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '17:05',
#   'latitude': 40.739185,
#   'longitude': -73.877785,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '13:10',
#   'latitude': 40.747032,
#   'longitude': -73.87937,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '15:40',
#   'latitude': 40.781387,
#   'longitude': -73.95213,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '13:22',
#   'latitude': 40.74608,
#   'longitude': -73.974945,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.777554,
#   'longitude': -73.94889,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '16:00',
#   'latitude': 40.700825,
#   'longitude': -73.89424,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '8:50',
#   'latitude': 40.814934,
#   'longitude': -73.91496,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '20:40',
#   'latitude': 40.709316,
#   'longitude': -73.93301,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '21:40',
#   'latitude': 40.838497,
#   'longitude': -73.939835,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '21:23',
#   'latitude': 40.814774,
#   'longitude': -73.94038,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-14T00:00:00.000',
#   'time': '11:35',
#   'latitude': 40.745796,
#   'longitude': -73.982285,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.762917,
#   'longitude': -73.98566,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '13:40',
#   'latitude': 40.75201,
#   'longitude': -73.93016,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '23:10',
#   'latitude': 40.66479,
#   'longitude': -73.91532,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '4:25',
#   'latitude': 40.702255,
#   'longitude': -73.937126,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '19:30',
#   'latitude': 40.757065,
#   'longitude': -74.00106,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '16:15',
#   'latitude': 40.60023,
#   'longitude': -73.9956,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '10:20',
#   'latitude': 40.8518,
#   'longitude': -73.909225,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '19:03',
#   'latitude': 40.61805,
#   'longitude': -73.98069,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.68746,
#   'longitude': -73.906494,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '21:15',
#   'latitude': 40.71472,
#   'longitude': -73.95846,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-26T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.667477,
#   'longitude': -73.95623,
#   'number_of_cyclist_injured': '2',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '12:45',
#   'latitude': 40.70938,
#   'longitude': -73.86964,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '18:07',
#   'latitude': 40.736137,
#   'longitude': -73.98512,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '8:12',
#   'latitude': 40.66061,
#   'longitude': -73.94262,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '17:44',
#   'latitude': 40.765823,
#   'longitude': -73.82373,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-14T00:00:00.000',
#   'time': '10:00',
#   'latitude': 40.711857,
#   'longitude': -74.00639,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '6:02',
#   'latitude': 40.768646,
#   'longitude': -73.96983,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '20:14',
#   'latitude': 40.794468,
#   'longitude': -73.93964,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '9:22',
#   'latitude': 40.578537,
#   'longitude': -74.10712,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '14:50',
#   'latitude': 40.642796,
#   'longitude': -74.00197,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '18:10',
#   'latitude': 40.58036,
#   'longitude': -73.96761,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-22T00:00:00.000',
#   'time': '16:09',
#   'latitude': 40.746246,
#   'longitude': -73.91524,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '8:54',
#   'latitude': 40.841652,
#   'longitude': -73.87233,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '16:05',
#   'latitude': 40.70058,
#   'longitude': -73.80775,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '15:15',
#   'latitude': 40.689144,
#   'longitude': -73.99071,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '19:15',
#   'latitude': 40.71414,
#   'longitude': -73.989136,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '12:15',
#   'latitude': 40.718544,
#   'longitude': -74.00072,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '19:45',
#   'latitude': 40.767517,
#   'longitude': -73.91203,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '19:49',
#   'latitude': 40.68269,
#   'longitude': -73.96168,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.70239,
#   'longitude': -73.924644,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '10:28',
#   'latitude': 40.706917,
#   'longitude': -73.93972,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '9:20',
#   'latitude': 40.68175,
#   'longitude': -73.96748,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '16:18',
#   'latitude': 40.70028,
#   'longitude': -73.941154,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '7:55',
#   'latitude': 40.760567,
#   'longitude': -73.9155,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '4:15',
#   'latitude': 40.66917,
#   'longitude': -73.98631,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.83727,
#   'longitude': -73.848785,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.566715,
#   'longitude': -74.13769,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '16:47',
#   'latitude': 40.678345,
#   'longitude': -73.985435,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '8:55',
#   'latitude': 40.681126,
#   'longitude': -73.96446,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '16:00',
#   'latitude': 40.723755,
#   'longitude': -73.89948,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '19:40',
#   'latitude': 40.84336,
#   'longitude': -73.845184,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.71126,
#   'longitude': -73.899864,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '22:30',
#   'latitude': 40.85064,
#   'longitude': -73.78809,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '17:25',
#   'latitude': 40.7169,
#   'longitude': -73.986206,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '19:15',
#   'latitude': 40.70719,
#   'longitude': -73.8973,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '20:30',
#   'latitude': 40.61721,
#   'longitude': -73.945076,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-08T00:00:00.000',
#   'time': '20:50',
#   'latitude': 40.616123,
#   'longitude': -73.979065,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '13:15',
#   'latitude': 40.815525,
#   'longitude': -73.85779,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '0:03',
#   'latitude': 40.69529,
#   'longitude': -73.94339,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '11:51',
#   'latitude': 40.785362,
#   'longitude': -73.946304,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '17:30',
#   'latitude': 40.731163,
#   'longitude': -73.99193,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '17:45',
#   'latitude': 40.68237,
#   'longitude': -73.864105,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-28T00:00:00.000',
#   'time': '19:35',
#   'latitude': 40.75836,
#   'longitude': -73.83154,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-28T00:00:00.000',
#   'time': '22:00',
#   'latitude': 40.670124,
#   'longitude': -73.95528,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '17:19',
#   'latitude': 40.748615,
#   'longitude': -73.87454,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '7:47',
#   'latitude': 40.702984,
#   'longitude': -73.81922,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '13:25',
#   'latitude': 40.85338,
#   'longitude': -73.93745,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '21:21',
#   'latitude': 40.680782,
#   'longitude': -73.975075,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '21:50',
#   'latitude': 40.70191,
#   'longitude': -73.93699,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '0:01',
#   'latitude': 40.683838,
#   'longitude': -73.95623,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-16T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.63366,
#   'longitude': -74.08232,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-26T00:00:00.000',
#   'time': '11:48',
#   'latitude': 40.68708,
#   'longitude': -73.913895,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '19:50',
#   'latitude': 40.684887,
#   'longitude': -73.83584,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '21:45',
#   'latitude': 40.702972,
#   'longitude': -73.888054,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '22:40',
#   'latitude': 40.77022,
#   'longitude': -73.83055,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.67816,
#   'longitude': -73.897484,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '13:41',
#   'latitude': 40.712593,
#   'longitude': -73.967735,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '20:00',
#   'latitude': 40.73975,
#   'longitude': -74.00253,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '16:50',
#   'latitude': 40.719997,
#   'longitude': -73.76198,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '21:00',
#   'latitude': 40.828976,
#   'longitude': -73.9486,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '18:19',
#   'latitude': 40.756058,
#   'longitude': -73.810234,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-14T00:00:00.000',
#   'time': '16:36',
#   'latitude': 40.666138,
#   'longitude': -73.948074,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '11:18',
#   'latitude': 40.6997,
#   'longitude': -73.94425,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '18:40',
#   'latitude': 40.763683,
#   'longitude': -73.98751,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-08T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.671654,
#   'longitude': -73.98093,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '21:25',
#   'latitude': 40.822903,
#   'longitude': -73.89689,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '1:01',
#   'latitude': 40.840286,
#   'longitude': -73.92147,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '13:14',
#   'latitude': 40.64161,
#   'longitude': -73.96356,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '8:02',
#   'latitude': 40.743156,
#   'longitude': -73.97213,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '19:35',
#   'latitude': 40.677162,
#   'longitude': -73.97245,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '2:10',
#   'latitude': 40.75112,
#   'longitude': -73.97127,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '13:07',
#   'latitude': 40.672047,
#   'longitude': -73.820404,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '6:50',
#   'latitude': 40.739113,
#   'longitude': -73.88975,
#   'number_of_cyclist_injured': '2',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '22:25',
#   'latitude': 40.72664,
#   'longitude': -73.99414,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '16:05',
#   'latitude': 40.659016,
#   'longitude': -73.95673,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '16:31',
#   'latitude': 40.609776,
#   'longitude': -73.9643,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '12:35',
#   'latitude': 40.67961,
#   'longitude': -73.98457,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '14:44',
#   'latitude': 40.761406,
#   'longitude': -73.80385,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-22T00:00:00.000',
#   'time': '12:00',
#   'latitude': 40.778606,
#   'longitude': -73.98163,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.765392,
#   'longitude': -73.9182,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '12:30',
#   'latitude': 40.605568,
#   'longitude': -74.00443,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '16:15',
#   'latitude': 40.76451,
#   'longitude': -73.97768,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '15:24',
#   'latitude': 40.865795,
#   'longitude': -73.920006,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '18:29',
#   'latitude': 40.712856,
#   'longitude': -73.977806,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '18:40',
#   'latitude': 40.75895,
#   'longitude': -73.83192,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '20:09',
#   'latitude': 40.717648,
#   'longitude': -73.98868,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '16:02',
#   'latitude': 40.632767,
#   'longitude': -73.95896,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '11:10',
#   'latitude': 40.663517,
#   'longitude': -73.957214,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '23:15',
#   'latitude': 40.58873,
#   'longitude': -73.94739,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-14T00:00:00.000',
#   'time': '10:40',
#   'latitude': 40.73136,
#   'longitude': -73.98257,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '16:41',
#   'latitude': 40.699707,
#   'longitude': -73.95072,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '16:45',
#   'latitude': 40.701332,
#   'longitude': -73.92684,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '11:52',
#   'latitude': 40.7005,
#   'longitude': -73.90116,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '11:30',
#   'latitude': 40.704224,
#   'longitude': -73.906235,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '9:25',
#   'latitude': 40.766876,
#   'longitude': -73.97908,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-01T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.804077,
#   'longitude': -73.91393,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '20:00',
#   'latitude': 40.67994,
#   'longitude': -73.88468,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '12:05',
#   'latitude': 40.749157,
#   'longitude': -73.86943,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '11:45',
#   'latitude': 40.853344,
#   'longitude': -73.881676,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '14:30',
#   'latitude': 40.774185,
#   'longitude': -73.81299,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '4:40',
#   'latitude': 40.86247,
#   'longitude': -73.90029,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-08T00:00:00.000',
#   'time': '20:40',
#   'latitude': 40.744778,
#   'longitude': -73.97589,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-02T00:00:00.000',
#   'time': '16:20',
#   'latitude': 40.707348,
#   'longitude': -73.82747,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '10:32',
#   'latitude': 40.66796,
#   'longitude': -73.87009,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '16:15',
#   'latitude': 40.657536,
#   'longitude': -73.902756,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '11:30',
#   'latitude': 40.62202,
#   'longitude': -73.98726,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.694275,
#   'longitude': -73.901855,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '17:40',
#   'latitude': 40.629295,
#   'longitude': -74.02869,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '9:10',
#   'latitude': 40.80417,
#   'longitude': -73.966705,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '14:15',
#   'latitude': 40.731834,
#   'longitude': -73.985306,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.741615,
#   'longitude': -73.993744,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.684387,
#   'longitude': -73.98657,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '23:30',
#   'latitude': 40.76548,
#   'longitude': -73.913704,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '11:02',
#   'latitude': 40.66955,
#   'longitude': -73.94497,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-27T00:00:00.000',
#   'time': '18:12',
#   'latitude': 40.641953,
#   'longitude': -73.9885,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '14:20',
#   'latitude': 40.683723,
#   'longitude': -73.96797,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '22:15',
#   'latitude': 40.681847,
#   'longitude': -73.92341,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.64829,
#   'longitude': -73.88034,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-22T00:00:00.000',
#   'time': '19:03',
#   'latitude': 40.838345,
#   'longitude': -73.8465,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '21:58',
#   'latitude': 40.72726,
#   'longitude': -73.982666,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-25T00:00:00.000',
#   'time': '10:14',
#   'latitude': 40.576275,
#   'longitude': -73.98796,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '6:54',
#   'latitude': 40.77918,
#   'longitude': -73.9508,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-29T00:00:00.000',
#   'time': '10:00',
#   'latitude': 40.75759,
#   'longitude': -73.98665,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-17T00:00:00.000',
#   'time': '15:23',
#   'latitude': 40.833427,
#   'longitude': -73.88005,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '15:55',
#   'latitude': 40.625698,
#   'longitude': -73.99466,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '8:55',
#   'latitude': 40.82966,
#   'longitude': -73.90725,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-30T00:00:00.000',
#   'time': '16:30',
#   'latitude': 40.79591,
#   'longitude': -73.93738,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '22:20',
#   'latitude': 40.738934,
#   'longitude': -73.79266,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-18T00:00:00.000',
#   'time': '18:35',
#   'latitude': 40.656147,
#   'longitude': -73.97732,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '18:00',
#   'latitude': 40.71977,
#   'longitude': -73.96232,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-03T00:00:00.000',
#   'time': '23:45',
#   'latitude': 40.82259,
#   'longitude': -73.93837,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-07-13T00:00:00.000',
#   'time': '20:22',
#   'latitude': 40.847664,
#   'longitude': -73.94219,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-05T00:00:00.000',
#   'time': '13:00',
#   'latitude': 40.769737,
#   'longitude': -73.91244,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '17:00',
#   'latitude': 40.731995,
#   'longitude': -73.99022,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-28T00:00:00.000',
#   'time': '16:45',
#   'latitude': 40.755817,
#   'longitude': -73.990845,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '12:29',
#   'latitude': 40.700672,
#   'longitude': -73.92164,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '18:40',
#   'latitude': 40.685,
#   'longitude': -73.96117,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-20T00:00:00.000',
#   'time': '14:15',
#   'latitude': 40.72766,
#   'longitude': -74.001396,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-06T00:00:00.000',
#   'time': '20:39',
#   'latitude': 40.748222,
#   'longitude': -73.87835,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-08T00:00:00.000',
#   'time': '19:06',
#   'latitude': 40.674133,
#   'longitude': -73.871605,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '19:25',
#   'latitude': 40.7222,
#   'longitude': -73.95755,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-23T00:00:00.000',
#   'time': '14:53',
#   'latitude': 40.758427,
#   'longitude': -73.99264,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-04T00:00:00.000',
#   'time': '17:05',
#   'latitude': 40.678154,
#   'longitude': -73.97117,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-15T00:00:00.000',
#   'time': '20:15',
#   'latitude': 40.695217,
#   'longitude': -73.841995,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-21T00:00:00.000',
#   'time': '0:50',
#   'latitude': 40.676273,
#   'longitude': -73.938774,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-28T00:00:00.000',
#   'time': '8:45',
#   'latitude': 40.69192,
#   'longitude': -73.97896,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-31T00:00:00.000',
#   'time': '9:09',
#   'latitude': 40.760773,
#   'longitude': -73.984474,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-19T00:00:00.000',
#   'time': '16:30',
#   'latitude': 40.624844,
#   'longitude': -74.027504,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-05-24T00:00:00.000',
#   'time': '20:06',
#   'latitude': 40.746525,
#   'longitude': -73.89113,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-07T00:00:00.000',
#   'time': '1:40',
#   'latitude': 40.80886,
#   'longitude': -73.95213,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2019-06-08T00:00:00.000',
#   'time': '9:00',
#   'latitude': 40.704853,
#   'longitude': -73.791664,
# ...
#   'longitude': -73.92196,
#   'number_of_cyclist_injured': '2',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-07T00:00:00.000',
#   'time': '9:30',
#   'latitude': 40.576588,
#   'longitude': -73.97151,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-28T00:00:00.000',
#   'time': '0:59',
#   'latitude': 40.833923,
#   'longitude': -73.876335,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-22T00:00:00.000',
#   'time': '13:45',
#   'latitude': 40.64367,
#   'longitude': -74.015495,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-05T00:00:00.000',
#   'time': '0:50',
#   'latitude': 40.68005,
#   'longitude': -73.94327,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-16T00:00:00.000',
#   'time': '16:20',
#   'latitude': 40.7145,
#   'longitude': -73.961296,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-30T00:00:00.000',
#   'time': '6:41',
#   'latitude': 40.58345,
#   'longitude': -73.950386,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-22T00:00:00.000',
#   'time': '17:51',
#   'latitude': 40.863647,
#   'longitude': -73.8918,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-29T00:00:00.000',
#   'time': '21:55',
#   'latitude': 40.86327,
#   'longitude': -73.87047,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-03T00:00:00.000',
#   'time': '3:58',
#   'latitude': 40.817303,
#   'longitude': -73.89791,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-16T00:00:00.000',
#   'time': '6:30',
#   'latitude': 40.758007,
#   'longitude': -73.96625,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-30T00:00:00.000',
#   'time': '14:10',
#   'latitude': 40.71718,
#   'longitude': -73.98311,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-30T00:00:00.000',
#   'time': '9:05',
#   'latitude': 40.8475,
#   'longitude': -73.86696,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-21T00:00:00.000',
#   'time': '18:55',
#   'latitude': 40.61565,
#   'longitude': -73.94474,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-27T00:00:00.000',
#   'time': '13:45',
#   'latitude': 40.749638,
#   'longitude': -73.99905,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-19T00:00:00.000',
#   'time': '19:35',
#   'latitude': 40.70213,
#   'longitude': -73.94432,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-22T00:00:00.000',
#   'time': '15:45',
#   'latitude': 40.69003,
#   'longitude': -73.911,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-31T00:00:00.000',
#   'time': '7:34',
#   'latitude': 40.60815,
#   'longitude': -73.95977,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-04T00:00:00.000',
#   'time': '22:10',
#   'latitude': 40.67737,
#   'longitude': -73.876274,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-11T00:00:00.000',
#   'time': '18:10',
#   'latitude': 40.763546,
#   'longitude': -73.969345,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-01T00:00:00.000',
#   'time': '15:03',
#   'latitude': 40.70299,
#   'longitude': -73.99471,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-19T00:00:00.000',
#   'time': '21:55',
#   'latitude': 40.82855,
#   'longitude': -73.85963,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-05T00:00:00.000',
#   'time': '19:25',
#   'latitude': 40.63765,
#   'longitude': -73.9528,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-20T00:00:00.000',
#   'time': '9:45',
#   'latitude': 40.85352,
#   'longitude': -73.902725,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-12T00:00:00.000',
#   'time': '16:05',
#   'latitude': 40.675312,
#   'longitude': -73.984604,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-27T00:00:00.000',
#   'time': '14:25',
#   'latitude': 40.697605,
#   'longitude': -73.92962,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-27T00:00:00.000',
#   'time': '22:00',
#   'latitude': 40.835297,
#   'longitude': -73.91291,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-25T00:00:00.000',
#   'time': '14:30',
#   'latitude': 40.73398,
#   'longitude': -73.99095,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-01T00:00:00.000',
#   'time': '17:06',
#   'latitude': 40.643745,
#   'longitude': -73.97009,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-06T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.581257,
#   'longitude': -73.957924,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-28T00:00:00.000',
#   'time': '17:40',
#   'latitude': 40.794907,
#   'longitude': -73.94856,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-20T00:00:00.000',
#   'time': '15:50',
#   'latitude': 40.889217,
#   'longitude': -73.866875,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-20T00:00:00.000',
#   'time': '13:00',
#   'latitude': 40.81632,
#   'longitude': -73.95783,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-07T00:00:00.000',
#   'time': '18:10',
#   'latitude': 40.79715,
#   'longitude': -73.97366,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-08T00:00:00.000',
#   'time': '21:45',
#   'latitude': 40.57563,
#   'longitude': -73.96395,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-22T00:00:00.000',
#   'time': '10:05',
#   'latitude': 40.866066,
#   'longitude': -73.89438,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-06T00:00:00.000',
#   'time': '17:03',
#   'latitude': 40.67947,
#   'longitude': -73.95313,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-02T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.719933,
#   'longitude': -73.97876,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-21T00:00:00.000',
#   'time': '7:33',
#   'latitude': 40.80167,
#   'longitude': -73.95096,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-28T00:00:00.000',
#   'time': '20:30',
#   'latitude': 40.53742,
#   'longitude': -74.174904,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-10T00:00:00.000',
#   'time': '18:45',
#   'latitude': 40.75184,
#   'longitude': -73.90358,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-23T00:00:00.000',
#   'time': '16:44',
#   'latitude': 40.691555,
#   'longitude': -73.93677,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-06T00:00:00.000',
#   'time': '11:24',
#   'latitude': 40.837315,
#   'longitude': -73.934044,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-15T00:00:00.000',
#   'time': '12:50',
#   'latitude': 40.708168,
#   'longitude': -73.95067,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-21T00:00:00.000',
#   'time': '9:05',
#   'latitude': 40.556534,
#   'longitude': -74.12813,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-04T00:00:00.000',
#   'time': '15:40',
#   'latitude': 40.843765,
#   'longitude': -73.8656,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-06T00:00:00.000',
#   'time': '23:09',
#   'latitude': 40.835884,
#   'longitude': -73.88341,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-23T00:00:00.000',
#   'time': '18:20',
#   'latitude': 40.638523,
#   'longitude': -73.98131,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-06T00:00:00.000',
#   'time': '9:24',
#   'latitude': 40.819572,
#   'longitude': -73.94993,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-20T00:00:00.000',
#   'time': '10:17',
#   'latitude': 40.590015,
#   'longitude': -74.09177,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-11T00:00:00.000',
#   'time': '3:45',
#   'latitude': 40.823257,
#   'longitude': -73.94293,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-07T00:00:00.000',
#   'time': '13:45',
#   'latitude': 40.8275,
#   'longitude': -73.886406,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-28T00:00:00.000',
#   'time': '12:30',
#   'latitude': 40.72605,
#   'longitude': -73.98354,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-22T00:00:00.000',
#   'time': '8:40',
#   'latitude': 40.630116,
#   'longitude': -74.108925,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-30T00:00:00.000',
#   'time': '11:56',
#   'latitude': 40.71979,
#   'longitude': -73.877266,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-14T00:00:00.000',
#   'time': '14:50',
#   'latitude': 40.83918,
#   'longitude': -73.94115,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-18T00:00:00.000',
#   'time': '21:50',
#   'latitude': 40.665916,
#   'longitude': -73.92547,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-24T00:00:00.000',
#   'time': '17:38',
#   'latitude': 40.604954,
#   'longitude': -73.745865,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-16T00:00:00.000',
#   'time': '13:08',
#   'latitude': 40.640762,
#   'longitude': -74.00767,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-04T00:00:00.000',
#   'time': '18:41',
#   'latitude': 40.738136,
#   'longitude': -74.0056,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-13T00:00:00.000',
#   'time': '15:00',
#   'latitude': 40.727642,
#   'longitude': -73.89251,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-16T00:00:00.000',
#   'time': '0:00',
#   'latitude': 40.766716,
#   'longitude': -73.928566,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-17T00:00:00.000',
#   'time': '22:40',
#   'latitude': 40.838497,
#   'longitude': -73.939835,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-01T00:00:00.000',
#   'time': '12:59',
#   'latitude': 40.67492,
#   'longitude': -73.836334,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-20T00:00:00.000',
#   'time': '12:30',
#   'latitude': 40.76889,
#   'longitude': -73.9821,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-18T00:00:00.000',
#   'time': '17:00',
#   'latitude': 40.740772,
#   'longitude': -73.89867,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-26T00:00:00.000',
#   'time': '23:50',
#   'latitude': 40.801815,
#   'longitude': -73.93929,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-23T00:00:00.000',
#   'time': '18:05',
#   'latitude': 40.86879,
#   'longitude': -73.83168,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-28T00:00:00.000',
#   'time': '21:20',
#   'latitude': 40.82696,
#   'longitude': -73.937195,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-04T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.8174,
#   'longitude': -73.83866,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-02T00:00:00.000',
#   'time': '17:10',
#   'latitude': 40.78517,
#   'longitude': -73.973145,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-14T00:00:00.000',
#   'time': '15:41',
#   'latitude': 40.78257,
#   'longitude': -73.94522,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-05T00:00:00.000',
#   'time': '19:45',
#   'latitude': 40.809105,
#   'longitude': -73.9229,
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '1'},
#  {'date': '2020-05-25T00:00:00.000',
#   'time': '0:37',
#   'latitude': 40.862534,
#   'longitude': -73.89708,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-28T00:00:00.000',
#   'time': '13:10',
#   'latitude': 40.650864,
#   'longitude': -73.93028,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-29T00:00:00.000',
#   'time': '14:25',
#   'latitude': 40.7025,
#   'longitude': -73.814964,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-11T00:00:00.000',
#   'time': '7:30',
#   'latitude': 40.76536,
#   'longitude': -73.98759,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-16T00:00:00.000',
#   'time': '21:30',
#   'latitude': 40.72377,
#   'longitude': -73.9508,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-09T00:00:00.000',
#   'time': '16:26',
#   'latitude': 40.697918,
#   'longitude': -73.9728,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-29T00:00:00.000',
#   'time': '17:20',
#   'latitude': 40.678898,
#   'longitude': -73.978775,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-04T00:00:00.000',
#   'time': '17:00',
#   'latitude': 40.70743,
#   'longitude': -73.95505,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-19T00:00:00.000',
#   'time': '19:00',
#   'latitude': 40.75296,
#   'longitude': -73.873535,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-29T00:00:00.000',
#   'time': '17:55',
#   'latitude': 40.679073,
#   'longitude': -73.92527,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-09T00:00:00.000',
#   'time': '23:33',
#   'latitude': 40.678276,
#   'longitude': -73.92467,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-06-14T00:00:00.000',
#   'time': '17:55',
#   'latitude': 40.65939,
#   'longitude': -73.96055,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-20T00:00:00.000',
#   'time': '12:25',
#   'latitude': 40.846138,
#   'longitude': -73.86172,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-11T00:00:00.000',
#   'time': '22:19',
#   'latitude': 40.785294,
#   'longitude': -73.969345,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-05-21T00:00:00.000',
#   'time': '18:30',
#   'latitude': 40.75415,
#   'longitude': -73.86791,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-19T00:00:00.000',
#   'time': '19:41',
#   'latitude': 40.80824,
#   'longitude': -73.95259,
#   'number_of_cyclist_injured': '2',
#   'number_of_cyclist_killed': '0'},
#  {'date': '2020-07-01T00:00:00.000',
#   'time': '19:15',
#   'latitude': 40.753986,
#   'longitude': -73.80769,
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0'},
#  ...]

# %%
def score_lane(data, lane):
    lane_dist = quick_dist(lane['first_coord'], lane['second_coord']) / 2
    for crash in data['crashes']:
        first_dist = quick_dist(lane['first_coord'], (crash['latitude'], crash['longitude']))
        second_dist = quick_dist(lane['second_coord'], (crash['latitude'], crash['longitude']))
        if lane_dist > first_dist or lane_dist > second_dist:
            try:
                lane['injuries'] += int(crash['number_of_cyclist_injured'])
                lane['deaths'] += int(crash['number_of_cyclist_killed'])
            except:
                lane['injuries'] = int(crash['number_of_cyclist_injured'])
                lane['deaths'] = int(crash['number_of_cyclist_killed'])
    return lane

# %%
def call_scoring_func(lane):
    return score_lane(data, lane)

# %%
def pool(data):
    with multiprocessing.Pool() as pool:
        multiproc = pool.map(call_scoring_func, data['lanes'])
    return multiproc

# %%
if __name__ == '__main__':
    threaded = pool(data)

# %%
def cds(data):
    actionable_data = []
    assembly_array = []
    count = 0
    for lane in data:
        newlane = lane
        count += 1
        for option in data:
            if quick_dist(lane['first_coord'], option['first_coord']) < 0.5 and lane['first_coord'] != option['first_coord'] and lane['second_coord'] != option['second_coord']:
                obj = {'first_coord': option['first_coord'], 'second_coord': option['second_coord'], 'type': option['type']}
                if 'injuries' in option.keys():
                    obj['injuries'] = option['injuries']
                if 'deaths' in option.keys():
                    obj['deaths'] = option['deaths']
                assembly_array.append(obj)
        newlane['options'] = assembly_array
        assembly_array = []
        if count % 5000 == 0:
            print(str(int(count/len(data)*100))+'%')
        actionable_data.append(newlane)
    return actionable_data

# %%
lane_data = cds(threaded)
# Out:
# 26%
# 53%
# 80%

# %%
# %load_ext sql
# %sql postgresql://alex:password@localhost:5432/alex
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn = psycopg2.connect(host="localhost", port = 5432, database="alex", user="alex", password="password")
cur = conn.cursor()
cur.execute("""CREATE TABLE IF NOT EXISTS lanes (first_coord_1 FLOAT, first_coord_2 FLOAT, second_coord_1 FLOAT, second_coord_2 FLOAT, type VARCHAR(50), injuries INT, deaths INT, id INT GENERATED ALWAYS AS IDENTITY);""")
for lane in lane_data:
    cur.execute("""INSERT INTO lanes (first_coord_1, first_coord_2, second_coord_1, second_coord_2, type, injuries, deaths) VALUES (%s, %s, %s, %s, %s, %s, %s);""", (lane['first_coord'][0], lane['first_coord'][1], lane['second_coord'][0], lane['second_coord'][1], lane['type'], lane['injuries'], lane['deaths']))
cur.execute("""SELECT * FROM lanes LIMIT 5;""")
query_results = cur.fetchall()
print(query_results)
conn.commit()
cur.close()
conn.close()
# Out:
# [(40.72315861141582, -73.87218201068114, 40.72352286351853, -73.87137759976227, 'Sharrows', 0, 0, 1), (40.57717211991796, -74.00066694563638, 40.577121471058895, -74.00110488656607, 'Standard', 0, 0, 2), (40.662347802483495, -73.84937839467118, 40.66217490965365, -73.84931944600652, 'Unknown', 0, 0, 3), (40.661046003203786, -73.97950974891293, 40.661099666912, -73.97926926441511, 'Greenway', 0, 0, 4), (40.72529744997435, -74.00921397183593, 40.72541007010525, -74.0091943858655, 'Unknown', 0, 0, 5)]
